# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Types of Noise

# %%
img = cv2.imread('rose.jpg')
img2 = cv2.imread('rose.jpg', 0)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(img2,cmap='gray',interpolation='bicubic')

# %%
def add_gaussian_noise(image_in, noise_sigma):
    temp_image = np.float64(np.copy(image_in))

    h = temp_image.shape[0]
    w = temp_image.shape[1]
    noise = np.random.randn(h, w) * noise_sigma

    noisy_image = np.zeros(temp_image.shape, np.float64)
    if len(temp_image.shape) == 2:
        noisy_image = temp_image + noise
    else:
        noisy_image[:,:,0] = temp_image[:,:,0] + noise
        noisy_image[:,:,1] = temp_image[:,:,1] + noise
        noisy_image[:,:,2] = temp_image[:,:,2] + noise

    """
    print('min,max = ', np.min(noisy_image), np.max(noisy_image))
    print('type = ', type(noisy_image[0][0][0]))
    """

    return noisy_image

img_g = add_gaussian_noise(img2,20)
plt.imshow(img_g,cmap='gray',interpolation='bicubic')

# %%
def add_salt_and_pepper(gb, prob):
    '''Adds "Salt & Pepper" noise to an image.
    gb: should be one-channel image with pixels in [0, 1] range
    prob: probability (threshold) that controls level of noise'''

    rnd = np.random.rand(gb.shape[0], gb.shape[1])
    noisy = gb.copy()
    noisy[rnd < prob] = 0
    noisy[rnd > 1 - prob] = 1
    return noisy

img_sp1 = add_salt_and_pepper(img2, 0.02)
plt.imshow(img_sp1,cmap='gray',interpolation='bicubic')

# %%
img_sp2 = add_salt_and_pepper(img2, 0.2)
plt.imshow(img_sp2,cmap='gray',interpolation='bicubic')

# %% [markdown]
# # Weiner Filter (Not Working)

# %%
img = cv2.imread('rose.jpg',0)
plt.imshow(img,cmap='gray',interpolation='bicubic')

# %%
img_g = add_gaussian_noise(img, 80)
plt.imshow(img_g,cmap='gray',interpolation='bicubic')

# %%
from skimage import color, data, restoration

#astro = color.rgb2gray(data.astronaut())
from scipy.signal import convolve2d as conv2
psf = np.ones((5, 5)) / 25
astro = conv2(img_g, psf, 'same')
astro += 0.1 * astro.std() * np.random.standard_normal(astro.shape)

deconvolved, _ = restoration.unsupervised_wiener(astro, psf)

# %%
plt.imshow(deconvolved,cmap='gray',interpolation='bicubic')

# %%
img2 = img_g - deconvolved

# %%
plt.imshow(img2,cmap='gray',interpolation='bicubic')

# %% [markdown]
# # Additional Quiz Material

# %%
img = np.random.randint(0,255,size = (100,100))

# %%
plt.imshow(img,cmap='gray',interpolation='bicubic')

# %%
img_2 = add_gaussian_noise(img,20)
plt.hist(img_2.ravel(),256,[0,256])
plt.show()

# %%
img3 = np.zeros((100,100))

# %%
plt.imshow(img3,cmap='gray',interpolation='bicubic')

# %%
img3_2 = add_gaussian_noise(img3,20)
plt.imshow(img3_2,cmap='gray',interpolation='bicubic')

# %%
plt.hist(img3_2.ravel(),256,[0,256])
plt.show()

# %%
img = cv2.imread('rose.jpg',0)
for i in range(0,(img.shape[0])):
    for j in range(0,(img.shape[1])):
        img[i,j] = 180

# %%
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2 = add_salt_and_pepper(img, 0.2)
cv2.imshow('image', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img3 = plt.hist(img2.ravel(),256,[0,256])
plt.show()
