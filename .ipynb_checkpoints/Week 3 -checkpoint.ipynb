# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('rose.jpg')

# %% [markdown]
# # Image Inversion

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
img2 = 255 - img

# %%
plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
plt.hist(img2.ravel(),256,[0,256]); plt.show()

# %%
img = cv2.imread('rose_grey.png',0)

# %%
plt.imshow(img,cmap='gray',interpolation='bicubic')

# %%
plt.hist(img.ravel(),256,[0,256])
plt.show()

# %%
img2 = 255 - img

# %%
plt.imshow(img2,cmap='gray',interpolation='bicubic')

# %%
plt.hist(img2.ravel(),256,[0,256])
plt.show()

# %% [markdown]
# # Histogram Equalization

# %%
# creating a Histograms Equalization 
# of a image using cv2.equalizeHist() 
equ = cv2.equalizeHist(img) 
  
# stacking images side-by-side 
res = np.hstack((img, equ))

# %%
plt.imshow(res,cmap='gray',interpolation='bicubic')

# %%
plt.imshow(equ,cmap='gray',interpolation='bicubic')

# %% [markdown]
# # Non Local Denoising
#
# http://demo.ipol.im/demo/bcm_non_local_means_denoising/

# %% [markdown]
# # Median Filter

# %%
def add_salt_and_pepper(gb, prob):
    '''Adds "Salt & Pepper" noise to an image.
    gb: should be one-channel image with pixels in [0, 1] range
    prob: probability (threshold) that controls level of noise'''

    rnd = np.random.rand(gb.shape[0], gb.shape[1])
    noisy = gb.copy()
    noisy[rnd < prob] = 0
    noisy[rnd > 1 - prob] = 1
    return noisy

# %%
img = cv2.imread('rose_grey.png',0)

# %%
plt.imshow(img,cmap='gray',interpolation='bicubic')

# %%
noisy = add_salt_and_pepper(img, 0.09)

# %%
plt.imshow(noisy,cmap='gray',interpolation='bicubic')

# %%
final = cv2.medianBlur(noisy, 3)

# %%
plt.imshow(final,cmap='gray',interpolation='bicubic')

# %% [markdown]
# # Unsharp Masking

# %%
img = cv2.imread('rose.jpg', 0)

# %%
plt.imshow(img,cmap='gray',interpolation='bicubic')

# %%
def add_salt_and_pepper(gb, prob):
    '''Adds "Salt & Pepper" noise to an image.
    gb: should be one-channel image with pixels in [0, 1] range
    prob: probability (threshold) that controls level of noise'''

    rnd = np.random.rand(gb.shape[0], gb.shape[1])
    noisy = gb.copy()
    noisy[rnd < prob] = 0
    noisy[rnd > 1 - prob] = 1
    return noisy

# %%
noisy = add_salt_and_pepper(img, 0.09)

# %%
plt.imshow(noisy,cmap='gray',interpolation='bicubic')

# %%
final = cv2.medianBlur(noisy, 3)
plt.imshow(final,cmap='gray',interpolation='bicubic')

# %%
diff = final - img
plt.imshow(diff,cmap='gray',interpolation='bicubic')

# %%
plt.imshow(diff**2,cmap='gray',interpolation='bicubic')
